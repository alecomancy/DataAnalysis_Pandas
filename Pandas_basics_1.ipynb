# %% [markdown]
# # The Begining for Learning Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Pandas Data Structures
# ### 1.1Series

# %% [markdown]
# A Series is a one-dimensional array like object,containing a sequence of **values and index**

# %%
obj = pd.Series([3,4,5,6])

# %%
obj
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
obj.values
# Out:
# array([3, 4, 5, 6], dtype=int64)

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Another way to think about Series is as a fixed length, ordered **dict**

# %% [markdown]
# ### 1.2 DataFrame

# %% [markdown]
# A DataFrame represents rectangular **table of data** and contains an ordered collection of **columns**.

# %%
data = {'state':['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],
        'year':[2000,2001,2002,2001,2002,2003],
        'pop':[1.5,1.7,3.6,2.4,2.9,3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# Rearrange **columns' order**:

# %%
pd.DataFrame(data,columns = ['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %% [markdown]
# A column can be **retrieved(returned)** as a Series
# ### All the column returned from indexing a DataFrame is a ***view***  on the underlying data, not a copy, use 'inplace = True' for any in-place modifications u want

# %%
frame['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame.state
#only works when the column name is a valid Python variable name
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %% [markdown]
# A row can also be retrieved as a Series

# %%
frame.loc[1]
# Out:
# state    Ohio
# year     2001
# pop       1.7
# Name: 1, dtype: object

# %% [markdown]
# Columns can be modified by assignent and assigning a column that **don't exist will create a new column**.

# %%
frame['eastern'] = frame.state == 'Ohio'

# %%
frame
# Out:
#     state  year  pop  eastern
# 0    Ohio  2000  1.5     True
# 1    Ohio  2001  1.7     True
# 2    Ohio  2002  3.6     True
# 3  Nevada  2001  2.4    False
# 4  Nevada  2002  2.9    False
# 5  Nevada  2003  3.2    False

# %%
frame['eastern'] = 'True'

# %%
frame
# Out:
#     state  year  pop eastern
# 0    Ohio  2000  1.5    True
# 1    Ohio  2001  1.7    True
# 2    Ohio  2002  3.6    True
# 3  Nevada  2001  2.4    True
# 4  Nevada  2002  2.9    True
# 5  Nevada  2003  3.2    True

# %% [markdown]
# #### del method to remove columns

# %%
del frame['eastern']

# %%
frame.columns
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
frame.values
# Out:
# array([['Ohio', 2000, 1.5],
#        ['Ohio', 2001, 1.7],
#        ['Ohio', 2002, 3.6],
#        ['Nevada', 2001, 2.4],
#        ['Nevada', 2002, 2.9],
#        ['Nevada', 2003, 3.2]], dtype=object)

# %% [markdown]
# ### 1.3 Index Objects

# %% [markdown]
# **pandas Index objects are responsible for holding the axis labels and other metadata.
# Index objects are immutable and make it safer to share it among data structures**

# %%
obj = pd.Series(range(3),index = ['a','b','c'])
index = obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
#index[1] = 'd'

# %% [markdown]
# Unlike python set, a pandas Index can contain duplicte lables. same methods like append,delete, drop...

# %%
dup_labels = pd.Index(['foo','foo','bar','bar'])
dup_labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %%
dup_labels.append(pd.Index(['ku']))
# Out:
# Index(['foo', 'foo', 'bar', 'bar', 'ku'], dtype='object')

# %% [markdown]
# ## 2. Essential functionality
# ### 2.1 reindexing

# %% [markdown]
# >reindex()
#
# Create a **new object** with the data conformed to a **new index**.

# %%
obj.reindex(['c' ,'b', 'a'])
# Out:
# c    2
# b    1
# a    0
# dtype: int64

# %% [markdown]
# ### 2.2 Droping entries from an axis

# %% [markdown]
# >obj.drop(inplace = False)
#
# Return a **new** object with the indicated value

# %%
obj.drop('c')
# Out:
# a    0
# b    1
# dtype: int64

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# You can drop values form the **columns** by passing **axis = 1 or axis = 'colomns'**

# %%
frame.drop('year', axis = 1)
# Out:
#     state  pop
# 0    Ohio  1.5
# 1    Ohio  1.7
# 2    Ohio  3.6
# 3  Nevada  2.4
# 4  Nevada  2.9
# 5  Nevada  3.2

# %% [markdown]
# **Many functions, like drop, which modify, can manipulate an object inplace without returning a new object**:
# >inplace=True

# %%
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj.drop('c', inplace = True)

# %%
obj
# Out:
# a    0
# b    1
# dtype: int64

# %% [markdown]
# **Slicing with labels** is different from normal Python

# %%
data = pd.DataFrame(np.arange(16).reshape((4,4)),
                    index = ['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns = ['one','two','three','four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[['three','one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %% [markdown]
# row selection: syntax data[:2] as a convenience
# column celection: a singer element or a list to the [] oprator

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False

# %% [markdown]
# ### 2.3 Selection with loc and iloc

# %% [markdown]
# >loc[ ]
#
# is for **axis** labels
# >iloc[ ]
#
# is for **integer** positioin
#
# Remenber to use **Brackets[ ]**

# %%
data.loc['Colorado',['two','three']]
# Out:
# two      5
# three    6
# Name: Colorado, dtype: int32

# %%
data.iloc[[1,2],[3,0,1]]
# Out:
#           four  one  two
# Colorado     7    4    5
# Utah        11    8    9
