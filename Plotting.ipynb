# %% [markdown]
# # Plotting and Visualization
# Focuse on **matplotlib**(mostly two-dimensional) and **seaborn**

# %% [markdown]
# ## 1. A Brief

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib notebook

# %% [markdown]
# ## 1.1 Figures and Subplots

# %% [markdown]
# Create a **Figure** object:
# >plt.figure(figsize=num)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# U can create one or more subplots by:
# >add_subplot(n, n, n)

# %%
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %% [markdown]
# When issue a plotting command like **plt.plot( [ ...])**, plt draws on the last figure and subplot used.

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins = 20, color = 'k', alpha = 0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))

# %% [markdown]
# >plt.subplots()
#
# Creates a new figure and retures a NumPy array containing the created subbplot objects

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000222172DBCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022217E9BB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022216C10F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022217272688>]],
#       dtype=object)

# %% [markdown]
# ### Adjusting the spacing around subplots

# %% [markdown]
# >subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
#
# wspace and hspace controls the percent of the figure width and figure height

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.rand(500), bins=50, color='k', alpha=0.5)

# %%
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# matplotlib doesn't check whether the **labels overlap.**
